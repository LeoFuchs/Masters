# %% [markdown]
# ### __Metadata from QGS with 1 topics and 6 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("systematic reviews") AND ("text" OR "paragraphs") AND ("based" OR "depends")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 3728 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 3784 results where 15 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 6 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("review" OR "critique" OR "reassessment") AND ("text" OR "paragraphs" OR "illustrations") AND ("systematic reviews") AND ("based" OR "depends" OR "headquartered")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 3732 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 3828 results where 15 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 6 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("based" OR "depends" OR "headquartered" OR "reflected")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 3732 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 3855 results where 15 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 1 topics and 7 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("systematic reviews") AND ("text" OR "paragraphs") AND ("based" OR "depends") AND ("learning" OR "knowledge")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 189 results where 10 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 663 results where 11 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 7 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("review" OR "critique" OR "reassessment") AND ("text" OR "paragraphs" OR "illustrations") AND ("systematic reviews") AND ("based" OR "depends" OR "headquartered") AND ("learning" OR "knowledge" OR "instruction")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 189 results where 10 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 693 results where 11 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 7 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 189 results where 10 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 696 results where 11 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 1 topics and 8 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("systematic reviews") AND ("text" OR "paragraphs") AND ("based" OR "depends") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 38 results where 9 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 65 results where 10 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 8 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("review" OR "critique" OR "reassessment") AND ("text" OR "paragraphs" OR "illustrations") AND ("systematic reviews") AND ("based" OR "depends" OR "headquartered") AND ("learning" OR "knowledge" OR "instruction") AND ("classification" OR "taxonomy" OR "re-classification")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 38 results where 9 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 68 results where 10 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 8 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 38 results where 9 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 68 results where 10 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 1 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification - machine} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification" AND "machine"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("text" OR "paragraphs") AND ("systematic reviews") AND ("based" OR "depends") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("machine" OR "computer")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 28 results where 8 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 35 results where 8 of the 46 QGS articles are present in the search </font>
#
#
# __Metadata from QGS with 1 topics and 9 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning - classification - machine} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning" AND "classification" AND "machine"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("review" OR "critique" OR "reassessment") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations") AND ("based" OR "depends" OR "headquartered") AND ("learning" OR "knowledge" OR "instruction") AND ("classification" OR "taxonomy" OR "re-classification") AND ("machine" OR "computer" OR "way-back")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 28 results where 8 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 35 results where 8 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 9 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - reviews - review - systematic reviews - text - based - learning - classification - machine} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "text" AND "based" AND "learning" AND "classification" AND "machine"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 28 results where 8 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 35 results where 8 of the 46 QGS articles are present in the search </font>
# __Metadata from QGS with 1 topics and 10 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification - machine - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification" AND "machine" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("text" OR "paragraphs") AND ("systematic reviews") AND ("based" OR "depends") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("machine" OR "computer") AND ("results" OR "findings")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 21 results where 6 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 27 results where 6 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 1 topics and 10 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification - machine - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification" AND "machine" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("text" OR "paragraphs") AND ("systematic reviews") AND ("based" OR "depends") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("machine" OR "computer") AND ("results" OR "findings")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 21 results where 6 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 27 results where 6 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 10 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification - machine - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification" AND "machine" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("review" OR "critique" OR "reassessment") AND ("text" OR "paragraphs" OR "illustrations") AND ("systematic reviews") AND ("based" OR "depends" OR "headquartered") AND ("learning" OR "knowledge" OR "instruction") AND ("classification" OR "taxonomy" OR "re-classification") AND ("machine" OR "computer" OR "way-back") AND ("results" OR "findings" OR "outcome")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 21 results where 6 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 28 results where 6 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 1 topics and 10 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 1 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - reviews - review - text - systematic reviews - based - learning - classification - machine - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "review" AND "text" AND "systematic reviews" AND "based" AND "learning" AND "classification" AND "machine" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("systematic reviews") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("results" OR "findings" OR "outcome" OR "analyses")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 21 results where 6 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 29 results where 6 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 4 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 4 words in textual format: <br>
# Topic 1: {systematic - text - mining - review} <br>
# Topic 2: {systematic - learning - reviews - machine} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review") OR ("systematic" AND "learning" AND "reviews" AND "machine"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 791 results where 32 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2814 results where 32 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 4 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 4 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine} <br>
# Topic 2: {systematic - text - mining - review} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine") OR ("systematic" AND "text" AND "mining" AND "review"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back")) OR (("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 791 results where 32 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 3406 results where 32 of the 46 QGS articles are present in the search </font>
#
# The 2 topics with your 4 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine} <br>
# Topic 2: {systematic - text - mining - review} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine") OR ("systematic" AND "text" AND "mining" AND "review"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 791 results where 32 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 3647 results where 32 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 5 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process} <br>
# Topic 2: {systematic - learning - reviews - machine - articles} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 302 results where 24 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 1300 results where 27 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 5 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles} <br>
# Topic 2: {systematic - text - mining - review - process} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals")) OR (("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 302 results where 24 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 1919 results where 28 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 5 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process} <br>
# Topic 2: {systematic - learning - reviews - machine - articles} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 302 results where 24 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2003 results where 28 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 6 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method") AND ("method" OR "procedure")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 176 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 735 results where 22 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 6 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system") AND ("method" OR "procedure" OR "approach")) OR (("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 176 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 1018 results where 23 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 6 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 6 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase") AND ("method" OR "procedure" OR "approach" OR "tactic")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 176 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 1070 results where 23 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 7 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method") AND ("method" OR "procedure") AND ("study" OR "research")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("classification" OR "taxonomy")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 90 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 231 results where 21 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 7 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification} <br>
# Topic 2: {systematic - text - mining - review - process - method - study} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered") AND ("classification" OR "taxonomy" OR "re-classification")) OR (("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system") AND ("method" OR "procedure" OR "approach") AND ("study" OR "research" OR "work")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 90 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 302 results where 22 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 7 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 7 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification} <br>
# Topic 2: {systematic - text - mining - review - process - method - study} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase") AND ("method" OR "procedure" OR "approach" OR "tactic") AND ("study" OR "research" OR "work" OR "analysis")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 90 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 329 results where 23 of the 46 QGS articles are present in the search </font>
#
# ____________________

# %% [markdown]
# __Metadata from QGS with 2 topics and 8 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study - literature} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method") AND ("method" OR "procedure") AND ("study" OR "research") AND ("literature" OR "poetry")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("classification" OR "taxonomy") AND ("systematic reviews")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 71 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 158 results where 21 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 8 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study - literature} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system") AND ("method" OR "procedure" OR "approach") AND ("study" OR "research" OR "work") AND ("literature" OR "poetry" OR "studies")) OR (("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered") AND ("classification" OR "taxonomy" OR "re-classification") AND ("systematic reviews")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 71 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 238 results where 22 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 8 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 8 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews} <br>
# Topic 2: {systematic - text - mining - review - process - method - study - literature} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("systematic reviews")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase") AND ("method" OR "procedure" OR "approach" OR "tactic") AND ("study" OR "research" OR "work" OR "analysis") AND ("literature" OR "poetry" OR "studies" OR "philosophy")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 71 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 247 results where 22 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study - literature - reviews} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method") AND ("method" OR "procedure") AND ("study" OR "research") AND ("literature" OR "poetry") AND ("reviews" OR "critiques")) OR (("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("classification" OR "taxonomy") AND ("systematic reviews") AND ("machine learning")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 70 results where 16 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 143 results where 21 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 9 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study - literature - reviews} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system") AND ("method" OR "procedure" OR "approach") AND ("study" OR "research" OR "work") AND ("literature" OR "poetry" OR "studies") AND ("reviews" OR "critiques" OR "mini-reviews")) OR (("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered") AND ("classification" OR "taxonomy" OR "re-classification") AND ("systematic reviews") AND ("machine learning")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 70 results where 16 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 218 results where 22 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 9 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
# The 2 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning} <br>
# Topic 2: {systematic - text - mining - review - process - method - study - literature - reviews} <br>
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("systematic reviews") AND ("machine learning")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase") AND ("method" OR "procedure" OR "approach" OR "tactic") AND ("study" OR "research" OR "work" OR "analysis") AND ("literature" OR "poetry" OR "studies" OR "philosophy") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 70 results where 16 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 227 results where 22 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 2 topics and 10 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning - review} <br>
# Topic 2: {systematic - text - mining - review - process - method - study - literature - reviews - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning" AND "review") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("learning" OR "knowledge") AND ("reviews" OR "critiques") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("classification" OR "taxonomy") AND ("systematic reviews") AND ("machine learning") AND ("review" OR "critique")) OR (("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("review" OR "critique") AND ("process" OR "method") AND ("method" OR "procedure") AND ("study" OR "research") AND ("literature" OR "poetry") AND ("reviews" OR "critiques") AND ("results" OR "findings")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 63 results where 14 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 123 results where 18 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 10 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process - method - study - literature - reviews - results} <br>
# Topic 2: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning - review} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews" AND "results") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning" AND "review"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "critique" OR "reassessment") AND ("process" OR "method" OR "system") AND ("method" OR "procedure" OR "approach") AND ("study" OR "research" OR "work") AND ("literature" OR "poetry" OR "studies") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("results" OR "findings" OR "outcome")) OR (("systematic" OR "methodical" OR "thorough") AND ("learning" OR "knowledge" OR "instruction") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered") AND ("classification" OR "taxonomy" OR "re-classification") AND ("systematic reviews") AND ("machine learning") AND ("review" OR "critique" OR "reassessment")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 63 results where 14 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 178 results where 19 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 2 topics and 10 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles - based - classification - systematic reviews - machine learning - review} <br>
# Topic 2: {systematic - text - mining - review - process - method - study - literature - reviews - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles" AND "based" AND "classification" AND "systematic reviews" AND "machine learning" AND "review") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "reviews" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("systematic reviews") AND ("machine learning") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("process" OR "method" OR "system" OR "phase") AND ("method" OR "procedure" OR "approach" OR "tactic") AND ("study" OR "research" OR "work" OR "analysis") AND ("literature" OR "poetry" OR "studies" OR "philosophy") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("results" OR "findings" OR "outcome" OR "analyses")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 63 results where 14 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 214 results where 19 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 3 topics and 7 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 3 topics with your 7 words in textual format: <br>
# Topic 1: {study - literature - process - systematic - review - mining - evidence} <br>
# Topic 2: {learning - machine - articles - based - machine learning - reviews - systematic} <br>
# Topic 3: {systematic - reviews - systematic reviews - text - systematic review - review - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("study" AND "literature" AND "process" AND "systematic" AND "review" AND "mining" AND "evidence") OR ("learning" AND "machine" AND "articles" AND "based" AND "machine learning" AND "reviews" AND "systematic") OR ("systematic" AND "reviews" AND "systematic reviews" AND "text" AND "systematic review" AND "review" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("study" OR "research") AND ("literature" OR "poetry") AND ("process" OR "method") AND ("systematic" OR "methodical") AND ("review" OR "critique") AND ("mining" OR "Open-pit") AND ("evidence" OR "circumstantial")) OR (("learning" OR "knowledge") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("machine learning") AND ("reviews" OR "critiques") AND ("systematic" OR "methodical")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("text" OR "paragraphs") AND ("systematic review") AND ("review" OR "critique") AND ("classification" OR "taxonomy")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 585 results where 22 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 682 results where 24 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 3 topics and 8 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 3 topics with your 8 words in textual format: <br>
# Topic 1: {learning - machine - articles - based - machine learning - methods - performance - evidence} <br>
# Topic 2: {mining - text - study - literature - systematic - process - support - review} <br>
# Topic 3: {systematic - reviews - review - systematic reviews - classification - systematic review - results - text} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("learning" AND "machine" AND "articles" AND "based" AND "machine learning" AND "methods" AND "performance" AND "evidence") OR ("mining" AND "text" AND "study" AND "literature" AND "systematic" AND "process" AND "support" AND "review") OR ("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "classification" AND "systematic review" AND "results" AND "text"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("learning" OR "knowledge") AND ("machine" OR "computer") AND ("articles" OR "pages") AND ("based" OR "depends") AND ("machine learning") AND ("methods" OR "strategies") AND ("performance" OR "achievement") AND ("evidence" OR "circumstantial")) OR (("mining" OR "Open-pit") AND ("text" OR "paragraphs") AND ("study" OR "research") AND ("literature" OR "poetry") AND ("systematic" OR "methodical") AND ("process" OR "method") AND ("support" OR "backing") AND ("review" OR "critique")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("systematic reviews") AND ("classification" OR "taxonomy") AND ("systematic review") AND ("results" OR "findings") AND ("text" OR "paragraphs")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 475 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 551 results where 16 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 3 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 3 topics with your 9 words in textual format: <br>
# Topic 1: {based - evidence - study - evidence based - research - relevant - literature - using - review} <br>
# Topic 2: {learning - systematic - machine - reviews - articles - machine learning - systematic reviews - classification - review} <br>
# Topic 3: {systematic - text - mining - process - review - method - reviews - results - support} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("based" AND "evidence" AND "study" AND "evidence based" AND "research" AND "relevant" AND "literature" AND "using" AND "review") OR ("learning" AND "systematic" AND "machine" AND "reviews" AND "articles" AND "machine learning" AND "systematic reviews" AND "classification" AND "review") OR ("systematic" AND "text" AND "mining" AND "process" AND "review" AND "method" AND "reviews" AND "results" AND "support"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("based" OR "depends") AND ("evidence" OR "circumstantial") AND ("study" OR "research") AND ("evidence based") AND ("research" OR "studies") AND ("relevant" OR "pertinent") AND ("literature" OR "poetry") AND ("using" OR "employing") AND ("review" OR "critique")) OR (("learning" OR "knowledge") AND ("systematic" OR "methodical") AND ("machine" OR "computer") AND ("reviews" OR "critiques") AND ("articles" OR "pages") AND ("machine learning") AND ("systematic reviews") AND ("classification" OR "taxonomy") AND ("review" OR "critique")) OR (("systematic" OR "methodical") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("process" OR "method") AND ("review" OR "critique") AND ("method" OR "procedure") AND ("reviews" OR "critiques") AND ("results" OR "findings") AND ("support" OR "backing")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 860 results where 18 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2016 results where 21 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 3 topics and 9 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 3 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - reviews - text - systematic reviews - review - mining - method - systematic review - classification} <br>
# Topic 2: {study - literature - process - evidence - systematic - review - based - results - mining} <br>
# Topic 3: {learning - machine - articles - systematic - machine learning - reviews - based - systematic reviews - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "text" AND "systematic reviews" AND "review" AND "mining" AND "method" AND "systematic review" AND "classification") OR ("study" AND "literature" AND "process" AND "evidence" AND "systematic" AND "review" AND "based" AND "results" AND "mining") OR ("learning" AND "machine" AND "articles" AND "systematic" AND "machine learning" AND "reviews" AND "based" AND "systematic reviews" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("text" OR "paragraphs" OR "illustrations") AND ("systematic reviews") AND ("review" OR "critique" OR "reassessment") AND ("mining" OR "Open-pit" OR "prospecting") AND ("method" OR "procedure" OR "approach") AND ("systematic review") AND ("classification" OR "taxonomy" OR "re-classification")) OR (("study" OR "research" OR "work") AND ("literature" OR "poetry" OR "studies") AND ("process" OR "method" OR "system") AND ("evidence" OR "circumstantial" OR "counter-evidence") AND ("systematic" OR "methodical" OR "thorough") AND ("review" OR "critique" OR "reassessment") AND ("based" OR "depends" OR "headquartered") AND ("results" OR "findings" OR "outcome") AND ("mining" OR "Open-pit" OR "prospecting")) OR (("learning" OR "knowledge" OR "instruction") AND ("machine" OR "computer" OR "way-back") AND ("articles" OR "pages" OR "journals") AND ("systematic" OR "methodical" OR "thorough") AND ("machine learning") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("based" OR "depends" OR "headquartered") AND ("systematic reviews") AND ("classification" OR "taxonomy" OR "re-classification")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 73 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 131 results where 16 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 3 topics and 9 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 3 topics with your 9 words in textual format: <br>
# Topic 1: {learning - machine - articles - based - machine learning - reviews - systematic - performance - using} <br>
# Topic 2: {systematic - reviews - systematic reviews - text - systematic review - review - classification - mining - method} <br>
# Topic 3: {study - literature - process - systematic - review - mining - evidence - results - text} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("learning" AND "machine" AND "articles" AND "based" AND "machine learning" AND "reviews" AND "systematic" AND "performance" AND "using") OR ("systematic" AND "reviews" AND "systematic reviews" AND "text" AND "systematic review" AND "review" AND "classification" AND "mining" AND "method") OR ("study" AND "literature" AND "process" AND "systematic" AND "review" AND "mining" AND "evidence" AND "results" AND "text"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("machine learning") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("performance" OR "achievement" OR "efficiency" OR "performance.The") AND ("using" OR "employing" OR "incorporating" OR "constructing")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("systematic review") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("method" OR "procedure" OR "approach" OR "tactic")) OR (("study" OR "research" OR "work" OR "analysis") AND ("literature" OR "poetry" OR "studies" OR "philosophy") AND ("process" OR "method" OR "system" OR "phase") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("evidence" OR "circumstantial" OR "counter-evidence" OR "evidence.") AND ("results" OR "findings" OR "outcome" OR "analyses") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 62 results where 12 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 95 results where 13 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 4 topics and 8 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 8 words in textual format: <br>
# Topic 1: {study - literature - process - systematic - review - results - mining - text} <br>
# Topic 2: {articles - using - machine - reviews - learning - classification - machine learning - systematic} <br>
# Topic 3: {systematic - reviews - systematic reviews - review - text - systematic review - classification - mining} <br>
# Topic 4: {learning - machine - based - machine learning - performance - evidence - methods - evidence based} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("study" AND "literature" AND "process" AND "systematic" AND "review" AND "results" AND "mining" AND "text") OR ("articles" AND "using" AND "machine" AND "reviews" AND "learning" AND "classification" AND "machine learning" AND "systematic") OR ("systematic" AND "reviews" AND "systematic reviews" AND "review" AND "text" AND "systematic review" AND "classification" AND "mining") OR ("learning" AND "machine" AND "based" AND "machine learning" AND "performance" AND "evidence" AND "methods" AND "evidence based"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("study" OR "research") AND ("literature" OR "poetry") AND ("process" OR "method") AND ("systematic" OR "methodical") AND ("review" OR "critique") AND ("results" OR "findings") AND ("mining" OR "Open-pit") AND ("text" OR "paragraphs")) OR (("articles" OR "pages") AND ("using" OR "employing") AND ("machine" OR "computer") AND ("reviews" OR "critiques") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("machine learning") AND ("systematic" OR "methodical")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("review" OR "critique") AND ("text" OR "paragraphs") AND ("systematic review") AND ("classification" OR "taxonomy") AND ("mining" OR "Open-pit")) OR (("learning" OR "knowledge") AND ("machine" OR "computer") AND ("based" OR "depends") AND ("machine learning") AND ("performance" OR "achievement") AND ("evidence" OR "circumstantial") AND ("methods" OR "strategies") AND ("evidence based")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 155 results where 23 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 219 results where 25 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 8 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 8 words in textual format: <br>
# Topic 1: {mining - text - literature - study - systematic - process - support - results} <br>
# Topic 2: {articles - based - using - relevant - evidence - classification - systematic - evidence based} <br>
# Topic 3: {learning - machine - machine learning - reviews - methods - performance - based - systematic reviews} <br>
# Topic 4: {systematic - review - reviews - systematic reviews - systematic review - classification - method - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("mining" AND "text" AND "literature" AND "study" AND "systematic" AND "process" AND "support" AND "results") OR ("articles" AND "based" AND "using" AND "relevant" AND "evidence" AND "classification" AND "systematic" AND "evidence based") OR ("learning" AND "machine" AND "machine learning" AND "reviews" AND "methods" AND "performance" AND "based" AND "systematic reviews") OR ("systematic" AND "review" AND "reviews" AND "systematic reviews" AND "systematic review" AND "classification" AND "method" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("mining" OR "Open-pit") AND ("text" OR "paragraphs") AND ("literature" OR "poetry") AND ("study" OR "research") AND ("systematic" OR "methodical") AND ("process" OR "method") AND ("support" OR "backing") AND ("results" OR "findings")) OR (("articles" OR "pages") AND ("based" OR "depends") AND ("using" OR "employing") AND ("relevant" OR "pertinent") AND ("evidence" OR "circumstantial") AND ("classification" OR "taxonomy") AND ("systematic" OR "methodical") AND ("evidence based")) OR (("learning" OR "knowledge") AND ("machine" OR "computer") AND ("machine learning") AND ("reviews" OR "critiques") AND ("methods" OR "strategies") AND ("performance" OR "achievement") AND ("based" OR "depends") AND ("systematic reviews")) OR (("systematic" OR "methodical") AND ("review" OR "critique") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("systematic review") AND ("classification" OR "taxonomy") AND ("method" OR "procedure") AND ("results" OR "findings")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 3973 results where 17 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 4683 results where 18 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 9 words in textual format: <br>
# Topic 1: {articles - using - used - time - study - literature - classification - reduce - relevant} <br>
# Topic 2: {text - mining - process - systematic - literature - study - support - review - results} <br>
# Topic 3: {systematic - reviews - review - systematic reviews - classification - based - systematic review - abstract - results} <br>
# Topic 4: {machine - machine learning - learning - performance - based - methods - support - systematic reviews - reviews} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("articles" AND "using" AND "used" AND "time" AND "study" AND "literature" AND "classification" AND "reduce" AND "relevant") OR ("text" AND "mining" AND "process" AND "systematic" AND "literature" AND "study" AND "support" AND "review" AND "results") OR ("systematic" AND "reviews" AND "review" AND "systematic reviews" AND "classification" AND "based" AND "systematic review" AND "abstract" AND "results") OR ("machine" AND "machine learning" AND "learning" AND "performance" AND "based" AND "methods" AND "support" AND "systematic reviews" AND "reviews"))
#
#
# String with improvement: <br>
# 	TITLE-ABS-KEY((("articles" OR "pages") AND ("using" OR "employing") AND ("used" OR "employed") AND ("time" OR "period") AND ("study" OR "research") AND ("literature" OR "poetry") AND ("classification" OR "taxonomy") AND ("reduce" OR "eliminate") AND ("relevant" OR "pertinent")) OR (("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("process" OR "method") AND ("systematic" OR "methodical") AND ("literature" OR "poetry") AND ("study" OR "research") AND ("support" OR "backing") AND ("review" OR "critique") AND ("results" OR "findings")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("review" OR "critique") AND ("systematic reviews") AND ("classification" OR "taxonomy") AND ("based" OR "depends") AND ("systematic review") AND ("abstract" OR "non-representational") AND ("results" OR "findings")) OR (("machine" OR "computer") AND ("machine learning") AND ("learning" OR "knowledge") AND ("performance" OR "achievement") AND ("based" OR "depends") AND ("methods" OR "strategies") AND ("support" OR "backing") AND ("systematic reviews") AND ("reviews" OR "critiques")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 221 results where 9 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 275 results where 13 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 9 words in textual format: <br>
# Topic 1: {mining - text - literature - process - study - systematic - support - techniques - results} <br>
# Topic 2: {learning - machine - machine learning - articles - reviews - systematic reviews - systematic - performance - classification} <br>
# Topic 3: {systematic - review - reviews - systematic reviews - systematic review - classification - method - results - abstract} <br>
# Topic 4: {based - evidence - evidence based - relevant - study - review - using - systematic - research} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("mining" AND "text" AND "literature" AND "process" AND "study" AND "systematic" AND "support" AND "techniques" AND "results") OR ("learning" AND "machine" AND "machine learning" AND "articles" AND "reviews" AND "systematic reviews" AND "systematic" AND "performance" AND "classification") OR ("systematic" AND "review" AND "reviews" AND "systematic reviews" AND "systematic review" AND "classification" AND "method" AND "results" AND "abstract") OR ("based" AND "evidence" AND "evidence based" AND "relevant" AND "study" AND "review" AND "using" AND "systematic" AND "research"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("mining" OR "Open-pit") AND ("text" OR "paragraphs") AND ("literature" OR "poetry") AND ("process" OR "method") AND ("study" OR "research") AND ("systematic" OR "methodical") AND ("support" OR "backing") AND ("techniques" OR "strategies") AND ("results" OR "findings")) OR (("learning" OR "knowledge") AND ("machine" OR "computer") AND ("machine learning") AND ("articles" OR "pages") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("systematic" OR "methodical") AND ("performance" OR "achievement") AND ("classification" OR "taxonomy")) OR (("systematic" OR "methodical") AND ("review" OR "critique") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("systematic review") AND ("classification" OR "taxonomy") AND ("method" OR "procedure") AND ("results" OR "findings") AND ("abstract" OR "non-representational")) OR (("based" OR "depends") AND ("evidence" OR "circumstantial") AND ("evidence based") AND ("relevant" OR "pertinent") AND ("study" OR "research") AND ("review" OR "critique") AND ("using" OR "employing") AND ("systematic" OR "methodical") AND ("research" OR "studies")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 1299 results where 11 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2744 results where 14 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 8 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 8 words in textual format: <br>
# Topic 1: {learning - machine - machine learning - performance - methods - systematic - based - review} <br>
# Topic 2: {articles - based - using - classification - reviews - systematic - systematic reviews - used} <br>
# Topic 3: {study - literature - process - systematic - review - evidence - support - text} <br>
# Topic 4: {systematic - reviews - systematic reviews - text - review - systematic review - classification - results} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("learning" AND "machine" AND "machine learning" AND "performance" AND "methods" AND "systematic" AND "based" AND "review") OR ("articles" AND "based" AND "using" AND "classification" AND "reviews" AND "systematic" AND "systematic reviews" AND "used") OR ("study" AND "literature" AND "process" AND "systematic" AND "review" AND "evidence" AND "support" AND "text") OR ("systematic" AND "reviews" AND "systematic reviews" AND "text" AND "review" AND "systematic review" AND "classification" AND "results"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("machine learning") AND ("performance" OR "achievement" OR "efficiency" OR "performance.The") AND ("methods" OR "strategies" OR "approaches" OR "procedures") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing")) OR (("articles" OR "pages" OR "journals" OR "stub-articles") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("using" OR "employing" OR "incorporating" OR "constructing") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("systematic reviews") AND ("used" OR "employed" OR "designed" OR "referred")) OR (("study" OR "research" OR "work" OR "analysis") AND ("literature" OR "poetry" OR "studies" OR "philosophy") AND ("process" OR "method" OR "system" OR "phase") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("evidence" OR "circumstantial" OR "counter-evidence" OR "evidence.") AND ("support" OR "backing" OR "help" OR "assistance") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic reviews") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("systematic review") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("results" OR "findings" OR "outcome" OR "analyses")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 797 results where 21 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2007 results where 24 of the 46 QGS articles are present in the search </font>

# %% [markdown]
# __Metadata from QGS with 4 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 9 words in textual format: <br>
# Topic 1: {literature - process - study - mining - systematic - support - text - review - techniques} <br>
# Topic 2: {systematic - reviews - text - systematic reviews - review - classification - method - systematic review - mining} <br>
# Topic 3: {evidence - based - evidence based - study - relevant - review - research - systematic - using} <br>
# Topic 4: {learning - machine - systematic - machine learning - articles - reviews - systematic reviews - performance - classification} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("literature" AND "process" AND "study" AND "mining" AND "systematic" AND "support" AND "text" AND "review" AND "techniques") OR ("systematic" AND "reviews" AND "text" AND "systematic reviews" AND "review" AND "classification" AND "method" AND "systematic review" AND "mining") OR ("evidence" AND "based" AND "evidence based" AND "study" AND "relevant" AND "review" AND "research" AND "systematic" AND "using") OR ("learning" AND "machine" AND "systematic" AND "machine learning" AND "articles" AND "reviews" AND "systematic reviews" AND "performance" AND "classification"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("literature" OR "poetry") AND ("process" OR "method") AND ("study" OR "research") AND ("mining" OR "Open-pit") AND ("systematic" OR "methodical") AND ("support" OR "backing") AND ("text" OR "paragraphs") AND ("review" OR "critique") AND ("techniques" OR "strategies")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("text" OR "paragraphs") AND ("systematic reviews") AND ("review" OR "critique") AND ("classification" OR "taxonomy") AND ("method" OR "procedure") AND ("systematic review") AND ("mining" OR "Open-pit")) OR (("evidence" OR "circumstantial") AND ("based" OR "depends") AND ("evidence based") AND ("study" OR "research") AND ("relevant" OR "pertinent") AND ("review" OR "critique") AND ("research" OR "studies") AND ("systematic" OR "methodical") AND ("using" OR "employing")) OR (("learning" OR "knowledge") AND ("machine" OR "computer") AND ("systematic" OR "methodical") AND ("machine learning") AND ("articles" OR "pages") AND ("reviews" OR "critiques") AND ("systematic reviews") AND ("performance" OR "achievement") AND ("classification" OR "taxonomy")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 976 results where 14 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 2359 results where 16 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 9 words. Improvement with more 2 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 9 words in textual format: <br>
# Topic 1: {literature - study - process - systematic - review - results - evidence - mining - support} <br>
# Topic 2: {machine - learning - articles - based - machine learning - reviews - systematic - using - systematic reviews} <br>
# Topic 3: {text - mining - systematic - reviews - systematic reviews - support - abstract - classification - results} <br>
# Topic 4: {systematic - review - systematic review - systematic reviews - reviews - method - classification - results - learning} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("literature" AND "study" AND "process" AND "systematic" AND "review" AND "results" AND "evidence" AND "mining" AND "support") OR ("machine" AND "learning" AND "articles" AND "based" AND "machine learning" AND "reviews" AND "systematic" AND "using" AND "systematic reviews") OR ("text" AND "mining" AND "systematic" AND "reviews" AND "systematic reviews" AND "support" AND "abstract" AND "classification" AND "results") OR ("systematic" AND "review" AND "systematic review" AND "systematic reviews" AND "reviews" AND "method" AND "classification" AND "results" AND "learning"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("literature" OR "poetry" OR "studies") AND ("study" OR "research" OR "work") AND ("process" OR "method" OR "system") AND ("systematic" OR "methodical" OR "thorough") AND ("review" OR "critique" OR "reassessment") AND ("results" OR "findings" OR "outcome") AND ("evidence" OR "circumstantial" OR "counter-evidence") AND ("mining" OR "Open-pit" OR "prospecting") AND ("support" OR "backing" OR "help")) OR (("machine" OR "computer" OR "way-back") AND ("learning" OR "knowledge" OR "instruction") AND ("articles" OR "pages" OR "journals") AND ("based" OR "depends" OR "headquartered") AND ("machine learning") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("systematic" OR "methodical" OR "thorough") AND ("using" OR "employing" OR "incorporating") AND ("systematic reviews")) OR (("text" OR "paragraphs" OR "illustrations") AND ("mining" OR "Open-pit" OR "prospecting") AND ("systematic" OR "methodical" OR "thorough") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("systematic reviews") AND ("support" OR "backing" OR "help") AND ("abstract" OR "non-representational" OR "non-figurative") AND ("classification" OR "taxonomy" OR "re-classification") AND ("results" OR "findings" OR "outcome")) OR (("systematic" OR "methodical" OR "thorough") AND ("review" OR "critique" OR "reassessment") AND ("systematic review") AND ("systematic reviews") AND ("reviews" OR "critiques" OR "mini-reviews") AND ("method" OR "procedure" OR "approach") AND ("classification" OR "taxonomy" OR "re-classification") AND ("results" OR "findings" OR "outcome") AND ("learning" OR "knowledge" OR "instruction")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 175 results where 16 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 744 results where 18 of the 46 QGS articles are present in the search </font>
#
# __Metadata from QGS with 4 topics and 9 words. Improvement with more 3 similar words and Levenshtein distance is 4__
#
#
# The 4 topics with your 9 words in textual format: <br>
# Topic 1: {literature - study - systematic - process - text - mining - review - results - support} <br>
# Topic 2: {learning - machine - machine learning - based - performance - evidence - methods - evidence based - reviews} <br>
# Topic 3: {articles - using - systematic - text - classification - reviews - systematic reviews - mining - relevant} <br>
# Topic 4: {systematic - review - reviews - systematic reviews - systematic review - method - classification - results - abstract} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("literature" AND "study" AND "systematic" AND "process" AND "text" AND "mining" AND "review" AND "results" AND "support") OR ("learning" AND "machine" AND "machine learning" AND "based" AND "performance" AND "evidence" AND "methods" AND "evidence based" AND "reviews") OR ("articles" AND "using" AND "systematic" AND "text" AND "classification" AND "reviews" AND "systematic reviews" AND "mining" AND "relevant") OR ("systematic" AND "review" AND "reviews" AND "systematic reviews" AND "systematic review" AND "method" AND "classification" AND "results" AND "abstract"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("literature" OR "poetry" OR "studies" OR "philosophy") AND ("study" OR "research" OR "work" OR "analysis") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("process" OR "method" OR "system" OR "phase") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("results" OR "findings" OR "outcome" OR "analyses") AND ("support" OR "backing" OR "help" OR "assistance")) OR (("learning" OR "knowledge" OR "instruction" OR "Student-centered") AND ("machine" OR "computer" OR "way-back" OR "tunnel-boring") AND ("machine learning") AND ("based" OR "depends" OR "headquartered" OR "reflected") AND ("performance" OR "achievement" OR "efficiency" OR "performance.The") AND ("evidence" OR "circumstantial" OR "counter-evidence" OR "evidence.") AND ("methods" OR "strategies" OR "approaches" OR "procedures") AND ("evidence based") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications")) OR (("articles" OR "pages" OR "journals" OR "stub-articles") AND ("using" OR "employing" OR "incorporating" OR "constructing") AND ("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "paragraphs" OR "illustrations" OR "excerpt") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic reviews") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("relevant" OR "pertinent" OR "appropriate" OR "applicable")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("review" OR "critique" OR "reassessment" OR "re-reviewing") AND ("reviews" OR "critiques" OR "mini-reviews" OR "publications") AND ("systematic reviews") AND ("systematic review") AND ("method" OR "procedure" OR "approach" OR "tactic") AND ("classification" OR "taxonomy" OR "re-classification" OR "classification.") AND ("results" OR "findings" OR "outcome" OR "analyses") AND ("abstract" OR "non-representational" OR "non-figurative" OR "semi-abstract")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 385 results where 10 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 554 results where 17 of the 46 QGS articles are present in the search </font>
