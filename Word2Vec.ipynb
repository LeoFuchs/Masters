# %% [markdown]
# # Tests with Word2Vec
#
# ## Test 1:
#
# **Complete data from QGS with 2 topics and 5 words. Improvement with more 2 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {studies - study - selection - process - review} <br>
# Topic 2: {data - set - systematic - review - learning}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("studies" AND "study" AND "selection" AND "process" AND "review") OR ("data" AND "set" AND "systematic" AND "review" AND "learning"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("studies" OR "study" OR "analyses") AND ("study" OR "studies" OR "Study") AND ("selection" OR "selections" OR "Selection") AND ("process" OR "processes" OR "processs") AND ("review" OR "reviews" OR "reviewing")) OR (("data" OR "Data" OR "datasets") AND ("set" OR "sets" OR "setting") AND ("systematic" OR "systematical" OR "Systematic") AND ("review" OR "reviews" OR "reviewing") AND ("learning" OR "teaching" OR "Learning")))
#
# **Results from Scopus Search:**
#
# String without improvement: 13,126 Results <br>
# String with improvement: 13,729 Results
#
# ---------------------------------
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 2 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process} <br>
# Topic 2: {systematic - learning - reviews - machine - articles}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "systematical" OR "Systematic") AND ("text" OR "Text" OR "texts") AND ("mining" OR "Mining" OR "mines") AND ("review" OR "reviews" OR "reviewing") AND ("process" OR "processes" OR "processs")) OR (("systematic" OR "systematical" OR "Systematic") AND ("learning" OR "teaching" OR "Learning") AND ("reviews" OR "Reviews" OR "review") AND ("machine" OR "machines" OR "Machine") AND ("articles" OR "aricles" OR "artices")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 300 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)<br><br>
# **String with improvement**: 301 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)</font>
#
# ---------------------------------
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 3 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process} <br>
# Topic 2: {systematic - learning - reviews - machine - articles}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "articles"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "systematical" OR "Systematic" OR "methodical") AND ("text" OR "Text" OR "texts" OR "text.") AND ("mining" OR "Mining" OR "mines" OR "Open-pit") AND ("review" OR "reviews" OR "reviewing" OR "reivew") AND ("process" OR "processes" OR "processs" OR "procedure")) OR (("systematic" OR "systematical" OR "Systematic" OR "methodical") AND ("learning" OR "teaching" OR "Learning" OR "learning-") AND ("reviews" OR "Reviews" OR "review" OR "reviewers") AND ("machine" OR "machines" OR "Machine" OR "machinery") AND ("articles" OR "aricles" OR "artices" OR "article")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 300 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)<br><br>
# **String with improvement**: 337 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)</font>
#
# ---------------------------------
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 5 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles} <br>
# Topic 2: {systematic - text - mining - review - process}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "systematical" OR "Systematic" OR "methodical" OR "systemic" OR "thorough") AND ("learning" OR "teaching" OR "Learning" OR "learning-" OR "education" OR "learner") AND ("reviews" OR "Reviews" OR "review" OR "reviewers" OR "reviews." OR "reviewer") AND ("machine" OR "machines" OR "Machine" OR "machinery" OR "Machines" OR "computer") AND ("articles" OR "aricles" OR "artices" OR "article" OR "pages" OR "aritcles")) OR (("systematic" OR "systematical" OR "Systematic" OR "methodical" OR "systemic" OR "thorough") AND ("text" OR "Text" OR "texts" OR "text." OR "text-" OR "paragraphs") AND ("mining" OR "Mining" OR "mines" OR "Open-pit" OR "miners" OR "prospecting") AND ("review" OR "reviews" OR "reviewing" OR "reivew" OR "reviewed" OR "reveiw") AND ("process" OR "processes" OR "processs" OR "procedure" OR "Process" OR "process.")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 300 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)<br><br>
# **String with improvement**: 1206 results where **24** of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 44, 45)</font>
#
# ---------------------------------
#
# ## Test 2:
#
# **Metadata data from QGS with 2 topics and 10 words. Improvement with more 2 similar words.** <br>
# **It was not allowed to use n gram greater than 1!**
#
# The 2 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - based - articles - classification - review - using - performance} <br>
# Topic 2: {systematic - text - mining - review - process - method - study - literature - results - reviews}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "based" AND "articles" AND "classification" AND "review" AND "using" AND "performance") OR ("systematic" AND "text" AND "mining" AND "review" AND "process" AND "method" AND "study" AND "literature" AND "results" AND "reviews"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "systematical" OR "Systematic") AND ("learning" OR "teaching" OR "Learning") AND ("reviews" OR "Reviews" OR "review") AND ("machine" OR "machines" OR "Machine") AND ("based" OR "basing" OR "Based") AND ("articles" OR "aricles" OR "artices") AND ("classification" OR "classifications" OR "Classification") AND ("review" OR "reviews" OR "reviewing") AND ("using" OR "utilizing" OR "employing") AND ("performance" OR "performances" OR "perfomance")) OR (("systematic" OR "systematical" OR "Systematic") AND ("text" OR "Text" OR "texts") AND ("mining" OR "Mining" OR "mines") AND ("review" OR "reviews" OR "reviewing") AND ("process" OR "processes" OR "processs") AND ("method" OR "methods" OR "technique") AND ("study" OR "studies" OR "Study") AND ("literature" OR "Literature" OR "literatures") AND ("results" OR "Results" OR "findings") AND ("reviews" OR "Reviews" OR "review")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 40 results where 9 of the 46 QGS articles are present in the search (QGS 9, 22, 26, 27, 35, 37, 41, 44, 45) <br>
# **String with improvement**: 47 Results where **9** of the 46 QGS articles are present in the search (QGS 9, 22, 26, 27, 35, 37, 41, 44, 45) </font>
#
# ## Test 3:
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 2 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - based} <br>
# Topic 2: {systematic - text - mining - review - process}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "based") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" AND "systematical" AND "Systematic") AND ("learning" AND "teaching" AND "Learning") AND ("reviews" AND "Reviews" AND "review") AND ("machine" AND "machines" AND "Machine") AND ("based" AND "basing" AND "Based")) OR (("systematic" AND "systematical" AND "Systematic") AND ("text" AND "Text" AND "texts") AND ("mining" AND "Mining" AND "mines") AND ("review" AND "reviews" AND "reviewing") AND ("process" AND "processes" AND "processs")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 376 results where **22** of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 32, 33, 35, 37, 41, 43, 44, 45) <br>
# **String with improvement**: 0 Results where **0** of the 46 QGS articles are present in the search. </font>
#
# QGS found with n-gram(1,3) : (QGS 1, 3, __5__ , 9, 10, 13, 15, 18, **19** , 22, 23, 26, 27, **29**, **30**, 32, 33, 35, **36**, 37, 41, **42**, 44, 45)
#
# QGS found with n-gram(1,1) : (QGS 1, 3, 9, 10, 13, 15, 18, **20**, **21**, 22, 23, **24**, 26, 27, 32, 33, 35, 37, 41, **43**, 44, 45)

# %% [markdown]
# # Tests with Word2Vec with Stemmings
#
# After the meeting, we decided to make a change, specifying that similar words should belong to a stemming other than the stemming of the original word. For this to happen a new version of the word2vec.py file was created and a battery of tests was performed again.
#
# ## Test 1:
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 2 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - based} <br>
# Topic 2: {systematic - text - mining - review - process}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "based") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough") AND ("learning" OR "teaching" OR "learning-") AND ("reviews" OR "reviews." OR "evaluations") AND ("machine" OR "machinery" OR "computer") AND ("based" OR "predicated" OR "relying")) OR (("systematic" OR "methodical" OR "thorough") AND ("text" OR "text." OR "text-") AND ("mining" OR "Open-pit" OR "prospecting") AND ("review" OR "reivew" OR "reveiw") AND ("process" OR "processs" OR "procedure")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 376 results where __22__ of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 32, 33, 35, 37, 41, 43, 44, 45)<br><br>
# **String with improvement**: 1580 results where **23** of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 29, 32, 33, 35, 37, 41, 43, 44, 45)</font>
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 3 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - text - mining - review - process} <br>
# Topic 2: {systematic - learning - reviews - machine - based}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "text" AND "mining" AND "review" AND "process") OR ("systematic" AND "learning" AND "reviews" AND "machine" AND "based"))
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("text" OR "text." OR "text-" OR "paragraphs") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining") AND ("review" OR "reivew" OR "reveiw" OR "re-review") AND ("process" OR "processs" OR "procedure" OR "process.")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate") AND ("learning" OR "teaching" OR "learning-" OR "education") AND ("reviews" OR "reviews." OR "evaluations" OR "critiques") AND ("machine" OR "machinery" OR "computer" OR "machine.") AND ("based" OR "predicated" OR "relying" OR "relies")))
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 376 results where __22__ of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 32, 33, 35, 37, 41, 43, 44, 45)<br><br>
#
# **String with improvement**: 2107 results where **23** of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 29, 32, 33, 35, 37, 41, 43, 44, 45)</font>
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 5 similar words.**
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - based} <br>
# Topic 2: {systematic - text - mining - review - process}
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "based") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate" OR "comprehensive" OR "sytematic") AND ("learning" OR "teaching" OR "learning-" OR "education" OR "knowledge" OR "reading") AND ("reviews" OR "reviews." OR "evaluations" OR "critiques" OR "reveiws" OR "mini-reviews") AND ("machine" OR "machinery" OR "computer" OR "machine." OR "way-back" OR "tunnel-boring") AND ("based" OR "predicated" OR "relying" OR "relies" OR "derived" OR "centered")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate" OR "comprehensive" OR "sytematic") AND ("text" OR "text." OR "text-" OR "paragraphs" OR "text--" OR "text.The") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining" OR "open-cast" OR "goldmining") AND ("review" OR "reivew" OR "reveiw" OR "re-review" OR "review." OR "pre-review") AND ("process" OR "processs" OR "procedure" OR "process." OR "proces" OR "proccess")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 376 results where __22__ of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 32, 33, 35, 37, 41, 43, 44, 45)<br><br>
# **String with improvement**: +5000 results where **23** of the 46 QGS articles are present in the search (QGS 1, 3, 9, 10, 13, 15, 18, 20, 21, 22, 23, 24, 26, 27, 29, 32, 33, 35, 37, 41, 43, 44, 45)</font>
#
# **Metadata from QGS with 2 topics and 5 words. Improvement with more 5 similar words. 3-gram! **
#
# The 2 topics with your 5 words in textual format: <br>
# Topic 1: {systematic - learning - reviews - machine - articles} <br>
# Topic 2: {systematic - text - mining - review - process} <br>
#
# String without improvement:
# TITLE-ABS-KEY(("systematic" AND "learning" AND "reviews" AND "machine" AND "articles") OR ("systematic" AND "text" AND "mining" AND "review" AND "process"))
#
# String with improvement:
# TITLE-ABS-KEY((("systematic" OR "methodical" OR "thorough" OR "deliberate" OR "comprehensive" OR "sytematic") AND ("learning" OR "teaching" OR "learning-" OR "education" OR "knowledge" OR "reading") AND ("reviews" OR "reviews." OR "evaluations" OR "critiques" OR "reveiws" OR "mini-reviews") AND ("machine" OR "machinery" OR "computer" OR "machine." OR "way-back" OR "tunnel-boring") AND ("articles" OR "aricles" OR "artices" OR "pages" OR "aritcles" OR "topics")) OR (("systematic" OR "methodical" OR "thorough" OR "deliberate" OR "comprehensive" OR "sytematic") AND ("text" OR "text." OR "text-" OR "paragraphs" OR "text--" OR "text.The") AND ("mining" OR "Open-pit" OR "prospecting" OR "gold-mining" OR "open-cast" OR "goldmining") AND ("review" OR "reivew" OR "reveiw" OR "re-review" OR "review." OR "pre-review") AND ("process" OR "processs" OR "procedure" OR "process." OR "proces" OR "proccess")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 301 results where __26__ of the 46 QGS articles are present in the search (QGS 1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 26, 27, 29, 30, 32, 33, 34, 35, 36, 37, 39, 41, 42, 44, 45)<br><br>
# **String with improvement**: 4527 results where **26** of the 46 QGS articles are present in the search (QGS
#             1, 3, 5, 9, 10, 13, 15, 18, 19, 22, 23, 24, 26, 27, 29, 30, 32, 33, 35, 36, 37, 41, 42, 43, 44, 45)</font>
