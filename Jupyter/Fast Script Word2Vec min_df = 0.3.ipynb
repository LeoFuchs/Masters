# %% [markdown]
# __Metadata from QGS with 2 topics and 10 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 10 words in textual format: <br>
# Topic 1: {systematic - reviews - learning - classification - systematic reviews - machine - based - review - articles - machine learning} <br>
# Topic 2: {systematic - selection - studies - text - mining - text mining - study - process - literature - review} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "reviews" AND "learning" AND "classification" AND "systematic reviews" AND "machine" AND "based" AND "review" AND "articles" AND "machine learning") OR ("systematic" AND "selection" AND "studies" AND "text" AND "mining" AND "text mining" AND "study" AND "process" AND "literature" AND "review"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("systematic reviews") AND ("machine" OR "computer") AND ("based" OR "depends") AND ("review" OR "critique") AND ("articles" OR "pages") AND ("machine learning")) OR (("systematic" OR "methodical") AND ("selection" OR "choice") AND ("studies" OR "analyses") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("text mining") AND ("study" OR "research") AND ("process" OR "method") AND ("literature" OR "poetry") AND ("review" OR "critique")))
#
#
# **Results from Scopus Search:**
#
# <font color='red'> **String without improvement**: 53 results where 14 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 58 results where 17 of the 46 QGS articles are present in the search </font>
#
# 14 Articles without improvement: <br>
# Dalal (2013) <br>
# Felizardo (2012) <br>
# Kim (2014) <br>
# Garcia adeva (2014) <br>
# Kouznetsov (2009) <br>
# Frunza (2011) <br>
# Martinez (2008) <br>
# Kim (2012) <br>
# Tomassetti (2011) <br>
# Shemilt (2014) <br>
# Cohen (2012) <br>
# Felizardo (2013) <br>
# Kouznetsov (2010) <br>
# Felizardo (2011) <br>
#
#
# +3 Articles with improvement: <br>
# Felizardo (2014) <br>
# Miwa (2014) <br>
# Millard (2016) <br>
#
#
#
# __Metadata from QGS with 2 topics and 9 words. Improvement with more 1 similar words and Levenshtein distance is 4__
#
#
# The 2 topics with your 9 words in textual format: <br>
# Topic 1: {systematic - selection - studies - text - mining - text mining - study - process - literature} <br>
# Topic 2: {systematic - reviews - learning - classification - systematic reviews - machine - based - review - articles} <br>
#
#
# String without improvement: <br>
# TITLE-ABS-KEY(("systematic" AND "selection" AND "studies" AND "text" AND "mining" AND "text mining" AND "study" AND "process" AND "literature") OR ("systematic" AND "reviews" AND "learning" AND "classification" AND "systematic reviews" AND "machine" AND "based" AND "review" AND "articles"))
#
#
# String with improvement: <br>
# TITLE-ABS-KEY((("systematic" OR "methodical") AND ("selection" OR "choice") AND ("studies" OR "analyses") AND ("text" OR "paragraphs") AND ("mining" OR "Open-pit") AND ("text mining") AND ("study" OR "research") AND ("process" OR "method") AND ("literature" OR "poetry")) OR (("systematic" OR "methodical") AND ("reviews" OR "critiques") AND ("learning" OR "knowledge") AND ("classification" OR "taxonomy") AND ("systematic reviews") AND ("machine" OR "computer") AND ("based" OR "depends") AND ("review" OR "critique") AND ("articles" OR "pages")))
#
#
# **Results from Scopus Search:**
#
# ...
# <font color='red'> **String without improvement**: 55 results where 15 of the 46 QGS articles are present in the search <br>
# **String with improvement**: 77 results where 17 of the 46 QGS articles are present in the search </font>
